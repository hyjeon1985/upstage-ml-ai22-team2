# %% [markdown]
# # 지리 정보 취합하기

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from lab_core.styles.viz import setup_global
from lab_core.util.path import raw_data_dir, ext_data_dir
from lab_core.hyj.data.clieaning import rename_columns
from lab_core.hyj.data.data_compare import compare_schema

setup_global()

# %%
train_path = raw_data_dir("train.csv")
test_path = raw_data_dir("test.csv")
k_apt_path = ext_data_dir("k-apt.csv")

train = pd.read_csv(train_path)
x_train = train.drop("target", axis=1)
y_train = train["target"]
test = pd.read_csv(test_path)
k_apt = pd.read_csv(k_apt_path)
# Out:
# /tmp/ipykernel_687475/3611018865.py:5: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv(train_path)

# %%
compared = compare_schema(left=x_train, right=k_apt, left_name="train", right_name="apt")
display(compared)
# Out:
#            col  in_left  in_right    presence train_dtype  train_n_rows  \
# 0   Unnamed: 0    False      True    only_apt        None           NaN
# 1       k-아파트명    False      True    only_apt        None           NaN
# 2      k-아파트코드    False      True    only_apt        None           NaN
# 3    kapt도로명주소    False      True    only_apt        None           NaN
# 4         거래유형     True     False  only_train      object     1118822.0
# ..         ...      ...       ...         ...         ...           ...
# 58    세대전기계약방법     True      True        both      object     1118822.0
# 59         좌표X     True      True        both     float64     1118822.0
# 60         좌표Y     True      True        both     float64     1118822.0
# 61        주차대수     True      True        both     float64     1118822.0
# 62     청소비관리형태     True      True        both      object     1118822.0
#
#     train_na_cnt  train_na_rate  train_non_na_cnt  train_nunique  ...  \
# 0            NaN            NaN               NaN            NaN  ...
# 1            NaN            NaN               NaN            NaN  ...
# 2            NaN            NaN               NaN            NaN  ...
# 3            NaN            NaN               NaN            NaN  ...
# 4            0.0       0.000000         1118822.0            3.0  ...
# ..           ...            ...               ...            ...  ...
# 58      878747.0       0.785422          240075.0            2.0  ...
# 59      869670.0       0.777309          249152.0          741.0  ...
# 60      869670.0       0.777309          249152.0          741.0  ...
# 61      869714.0       0.777348          249108.0          526.0  ...
# 62      871178.0       0.778656          247644.0            4.0  ...
#
#    apt_dtype apt_n_rows apt_na_cnt  apt_na_rate  apt_non_na_cnt  apt_nunique  \
# 0      int64     2852.0        0.0     0.000000          2852.0       2852.0
# 1     object     2852.0        0.0     0.000000          2852.0       2842.0
# 2     object     2852.0        0.0     0.000000          2852.0       2852.0
# 3     object     2852.0       64.0     0.022440          2788.0       2707.0
# 4       None        NaN        NaN          NaN             NaN          NaN
# ..       ...        ...        ...          ...             ...          ...
# 58    object     2852.0      200.0     0.070126          2652.0          2.0
# 59   float64     2852.0       40.0     0.014025          2812.0       2765.0
# 60   float64     2852.0       40.0     0.014025          2812.0       2766.0
# 61   float64     2852.0       39.0     0.013675          2813.0       1113.0
# 62    object     2852.0       83.0     0.029102          2769.0          4.0
#
#                                        apt_top_values  \
# 0                                 0:1; 1916:1; 1896:1
# 1                   '신동아아파트':3; '우리유앤미':2; '경남아너스빌':2
# 2         'A15679103':1; 'A13579505':1; 'A13552001':1
# 3   '서울특별시 성북구 종암로23길 35':3; '서울특별시 강남구 개포로 310':2...
# 4                                                None
# ..                                                ...
# 58                           '종합계약':1351; '단일계약':1301
# 59        126.9764363:5; 127.0144609:3; 126.8195884:2
# 60           37.4886826:5; 37.5464825:3; 37.4785869:2
# 61                          0.0:223; 200.0:14; 1.0:14
# 62                       '위탁':2419; '직영':269; '기타':43
#
#                                           apt_samples dtype_mismatch  \
# 0                                             0, 1, 2          False
# 1                 '우리유앤미', '송파파인타운13단지', '오금현대백조(임대)'          False
# 2               'A15679103', 'A13876112', 'A13873701'          False
# 3   '서울특별시 동작구 서달로 83', '서울특별시 송파구 송파대로8길 10', '서울...          False
# 4                                                None          False
# ..                                                ...            ...
# 58                             '단일계약', '단일계약', '단일계약'          False
# 59              126.9596386, 127.1291789, 127.1287745          False
# 60                 37.5006676, 37.4768967, 37.5089058          False
# 61                                 223.0, 225.0, 60.0          False
# 62                                   '위탁', '위탁', '위탁'          False
#
#    na_rate_diff
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 58     0.715295
# 59     0.763283
# 60     0.763283
# 61     0.763673
# 62     0.749554
#
# [63 rows x 22 columns]
